# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle as pk
import warnings
warnings.filterwarnings('ignore')

df = pd.read_excel("parkinsons.xlsx")

pd.set_option('display.max_columns',None)

df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %% [markdown]
# ***Pre-Processing***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df.status.value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
df.drop('name',axis=1,inplace=True)

# %%
df.rename(columns={'status':'parkinsons_disease'},inplace=True)

# %%
# Feature selection with correaltion
df.corr()
# Out:
#                     MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)            1.000000      0.400985      0.596546       -0.118003
# MDVP:Fhi(Hz)           0.400985      1.000000      0.084951        0.102086
# MDVP:Flo(Hz)           0.596546      0.084951      1.000000       -0.139919
# MDVP:Jitter(%)        -0.118003      0.102086     -0.139919        1.000000
# MDVP:Jitter(Abs)      -0.382027     -0.029198     -0.277815        0.935714
# MDVP:RAP              -0.076194      0.097177     -0.100519        0.990276
# MDVP:PPQ              -0.112165      0.091126     -0.095828        0.974256
# Jitter:DDP            -0.076213      0.097150     -0.100488        0.990276
# MDVP:Shimmer          -0.098374      0.002281     -0.144543        0.769063
# MDVP:Shimmer(dB)      -0.073742      0.043465     -0.119089        0.804289
# Shimmer:APQ3          -0.094717     -0.003743     -0.150747        0.746625
# ...

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
correaltion_matrix = df.corr()

thershold =0.3

target_column = 'parkinsons_disease'

high_corr = correaltion_matrix[target_column][correaltion_matrix[target_column].abs() > thershold].index.tolist()

high_corr.remove(target_column)

print(high_corr)
# Out:
# ['MDVP:Fo(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(Abs)', 'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5', 'MDVP:APQ', 'Shimmer:DDA', 'HNR', 'RPDE', 'spread1', 'spread2', 'D2', 'PPE']

# %% [markdown]
# ***Model Splitting and fitting***

# %%
x = df[['MDVP:Fo(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(Abs)', 'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5', 'MDVP:APQ', 'Shimmer:DDA', 'HNR', 'RPDE', 'spread1', 'spread2', 'D2', 'PPE']]
x
# Out:
#      MDVP:Fo(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(Abs)  MDVP:Shimmer  \
# 0        119.992        74.997           0.00007       0.04374
# 1        122.400       113.819           0.00008       0.06134
# 2        116.682       111.555           0.00009       0.05233
# 3        116.676       111.366           0.00009       0.05492
# 4        116.014       110.655           0.00011       0.06425
# ..           ...           ...               ...           ...
# 190      174.188        94.261           0.00003       0.04087
# 191      209.516        89.488           0.00003       0.02751
# 192      174.688        74.287           0.00008       0.02308
# 193      198.764        74.904           0.00004       0.02296
# 194      214.289        77.973           0.00003       0.01884
#
#      MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  \
# 0               0.426       0.02182       0.03130   0.02971      0.06545
# ...

# %%
x = df[['MDVP:Fo(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(Abs)', 'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5', 'MDVP:APQ', 'Shimmer:DDA', 'HNR', 'RPDE', 'spread1', 'spread2', 'D2', 'PPE']]
y = df['parkinsons_disease']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((156, 15), (39, 15), (156,), (39,))

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ***Model Evaluation***

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

y_pred = lr.predict(x_test)

# %%
lr.score(x_test,y_test)
# Out:
# 0.8461538461538461

# %%
conn = confusion_matrix(y_test,y_pred)
conn
# Out:
# array([[ 3,  5],
#        [ 1, 30]])

# %%
sns.heatmap(conn,annot=True)
plt.show()

# %%
class_report = classification_report(y_test,y_pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.38      0.50         8
#            1       0.86      0.97      0.91        31
#
#     accuracy                           0.85        39
#    macro avg       0.80      0.67      0.70        39
# weighted avg       0.84      0.85      0.83        39

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8461538461538461

# %%
with open('Parkinson_disease_prediction.pkl','wb') as f:
    pk.dump(lr,f)

# %% [markdown]
# Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=100)

rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rfc.score(x_test,y_test)
# Out:
# 0.8717948717948718

# %% [markdown]
# Hyperparameter Tuning with GridSearch-CV

# %%
from sklearn.model_selection import GridSearchCV

param_grid ={
    'n_estimators':[100,200,300],
    'max_depth':[None,10,20,30],
    'min_samples_split':[2,5,10],
    'min_samples_leaf':[1,2,4],
    'max_features':['sqrt','log2']
}

grid_search = GridSearchCV(RandomForestClassifier(),param_grid,cv=5,n_jobs=-1,verbose=1)
grid_search.fit(x_train,y_train)

print("Best Parameter :", grid_search.best_params_)


best_rfc = RandomForestClassifier(**grid_search.best_params_)
best_rfc.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# Best Parameter : {'max_depth': 30, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# RandomForestClassifier(max_depth=30, max_features='log2')

# %%
accuracy = best_rfc.score(x_test,y_test)
print("Best optimized model : ",accuracy)
# Out:
# Best optimized model :  0.8205128205128205
